# %%
import gradio as gr

# %%
def greet(text):
    print(f"shout has been called with input{text}")
    return text.upper()

greet ("example text")
# Out:
# shout has been called with inputexample text
# 'EXAMPLE TEXT'

# %%
simple_chat = gr.Interface(fn = greet, inputs = "textbox", outputs = "textbox", flagging_mode = "never")
# Out:
# C:\Users\Reatlegile\AppData\Local\Temp\ipykernel_17640\2105940887.py:1: GradioUnusedKwargWarning: You have unused kwarg parameters in Interface, please remove them: {'flagging_mode': 'never'}
#   simple_chat = gr.Interface(fn = greet, inputs = "textbox", outputs = "textbox", flagging_mode = "never")
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------

# %%
simple_chat.launch(share = True)
